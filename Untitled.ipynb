# %%
# importing dependencies 
import pandas as pd

# %%
# Cleaning national shark data
sharkAttacks = pd.read_csv('data/attacks.csv', encoding='cp1252').drop(columns=['Unnamed: 22', 'Unnamed: 23'])
sharkAttacks.drop(columns=['Time'])
sharkAttacks.dropna()
# Out:
#        Case Number         Date    Year        Type    Country          Area  \
# 0       2018.06.25  25-Jun-2018  2018.0     Boating        USA    California
# 6     2018.06.03.a  03-Jun-2018  2018.0  Unprovoked     BRAZIL    Pernambuco
# 8     2018.05.26.b  26-May-2018  2018.0  Unprovoked        USA       Florida
# 10      2018.05.24  24-May-2018  2018.0    Provoked  AUSTRALIA    Queensland
# 13    2018.05.13.a  13-May-2018  2018.0     Invalid    ENGLAND      Cornwall
# ...            ...          ...     ...         ...        ...           ...
# 5814    1880.11.25  25-Nov-1880  1880.0  Unprovoked  AUSTRALIA    Queensland
# 5922    1868.05.13  13-May-1868  1868.0  Unprovoked      INDIA  Hoogly River
# 6242       ND.0064        1960s     0.0  Unprovoked       IRAQ        Basrah
# 6243       ND.0063        1960s     0.0  Unprovoked       IRAQ        Basrah
# 6265       ND.0038    1941-1942     0.0  Unprovoked       IRAQ        Basrah
#
# ...

# %%
sharkAttacks['Country'].unique()
# Out:
# array(['USA', 'AUSTRALIA', 'MEXICO', 'BRAZIL', 'ENGLAND', 'SOUTH AFRICA',
#        'THAILAND', 'COSTA RICA', 'MALDIVES', 'BAHAMAS', 'NEW CALEDONIA',
#        'ECUADOR', 'MALAYSIA', 'LIBYA', nan, 'CUBA', 'MAURITIUS',
#        'NEW ZEALAND', 'SPAIN', 'SAMOA', 'SOLOMON ISLANDS', 'JAPAN',
#        'EGYPT', 'ST HELENA, British overseas territory', 'COMOROS',
#        'REUNION', 'FRENCH POLYNESIA', 'UNITED KINGDOM',
#        'UNITED ARAB EMIRATES', 'PHILIPPINES', 'INDONESIA', 'CHINA',
#        'COLUMBIA', 'CAPE VERDE', 'Fiji', 'DOMINICAN REPUBLIC',
#        'CAYMAN ISLANDS', 'ARUBA', 'MOZAMBIQUE', 'FIJI', 'PUERTO RICO',
#        'ITALY', 'ATLANTIC OCEAN', 'GREECE', 'ST. MARTIN', 'FRANCE',
#        'PAPUA NEW GUINEA', 'TRINIDAD & TOBAGO', 'KIRIBATI', 'ISRAEL',
#        'DIEGO GARCIA', 'TAIWAN', 'JAMAICA', 'PALESTINIAN TERRITORIES',
#        'GUAM', 'SEYCHELLES', 'BELIZE', 'NIGERIA', 'TONGA', 'SCOTLAND',
#        'CANADA', 'CROATIA', 'SAUDI ARABIA', 'CHILE', 'ANTIGUA', 'KENYA',
# ...

# %%
# reading in csv for USA state lat and long
lat_long = pd.read_csv('data/Lat_long_states.csv')
lat_long
# Out:
#    State        Lat        Long
# 0     WI  44.500000  -89.500000
# 1     WV  39.000000  -80.500000
# 2     VT  44.000000  -72.699997
# 3     TX  31.000000 -100.000000
# 4     SD  44.500000 -100.000000
# 5     RI  41.700001  -71.500000
# 6     OR  44.000000 -120.500000
# 7     NY  43.000000  -75.000000
# 8     NH  44.000000  -71.500000
# 9     NE  41.500000 -100.000000
# 10    KS  38.500000  -98.000000
# 11    MS  33.000000  -90.000000
# 12    IL  40.000000  -89.000000
# 13    DE  39.000000  -75.500000
# 14    CT  41.599998  -72.699997
# 15    AR  34.799999  -92.199997
# 16    IN  40.273502  -86.126976
# 17    MO  38.573936  -92.603760
# 18    FL  27.994402  -81.760254
# 19    NV  39.876019 -117.224121
# 20    ME  45.367584  -68.972168
# 21    MI  44.182205  -84.506836
# 22    GA  33.247875  -83.441162
# 23    HI  19.741755 -155.844437
# 24    AK  66.160507 -153.369141
# 25    TN  35.860119  -86.660156
# 26    VA  37.926868  -78.024902
# 27    NJ  39.833851  -74.871826
# ...

# %%
# Creating dict of state names and abbriviations 
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# %%
# Writting dict to dataframe 
us_state_abbrev_df = pd.DataFrame.from_dict(us_state_abbrev, orient='index')

indexed = us_state_abbrev_df.reset_index()

indexed.columns = ['Area','State']
indexed
# Out:
#                         Area State
# 0                    Alabama    AL
# 1                     Alaska    AK
# 2             American Samoa    AS
# 3                    Arizona    AZ
# 4                   Arkansas    AR
# 5                 California    CA
# 6                   Colorado    CO
# 7                Connecticut    CT
# 8                   Delaware    DE
# 9       District of Columbia    DC
# 10                   Florida    FL
# 11                   Georgia    GA
# 12                      Guam    GU
# 13                    Hawaii    HI
# 14                     Idaho    ID
# 15                  Illinois    IL
# 16                   Indiana    IN
# 17                      Iowa    IA
# 18                    Kansas    KS
# 19                  Kentucky    KY
# 20                 Louisiana    LA
# 21                     Maine    ME
# 22                  Maryland    MD
# 23             Massachusetts    MA
# 24                  Michigan    MI
# 25                 Minnesota    MN
# ...

# %%
# merging state and lat long into one dataframe 
indexed.merge(lat_long, left_on='State', right_on='State')
# Out:
#               Area State        Lat        Long
# 0          Alabama    AL  32.318230  -86.902298
# 1           Alaska    AK  66.160507 -153.369141
# 2          Arizona    AZ  34.048927 -111.093735
# 3         Arkansas    AR  34.799999  -92.199997
# 4       California    CA  36.778259 -119.417931
# 5         Colorado    CO  39.113014 -105.358887
# 6      Connecticut    CT  41.599998  -72.699997
# 7         Delaware    DE  39.000000  -75.500000
# 8          Florida    FL  27.994402  -81.760254
# 9          Georgia    GA  33.247875  -83.441162
# 10          Hawaii    HI  19.741755 -155.844437
# 11           Idaho    ID  44.068203 -114.742043
# 12        Illinois    IL  40.000000  -89.000000
# 13         Indiana    IN  40.273502  -86.126976
# 14            Iowa    IA  42.032974  -93.581543
# 15          Kansas    KS  38.500000  -98.000000
# 16        Kentucky    KY  37.839333  -84.270020
# 17       Louisiana    LA  30.391830  -92.329100
# 18           Maine    ME  45.367584  -68.972168
# ...

# %%
sharkAttacks.loc[sharkAttacks['Country'] == 'AUSTRALIA']
# Out:
#        Case Number         Date    Year          Type    Country  \
# 3       2018.06.08  08-Jun-2018  2018.0    Unprovoked  AUSTRALIA
# 5     2018.06.03.b  03-Jun-2018  2018.0    Unprovoked  AUSTRALIA
# 10      2018.05.24  24-May-2018  2018.0      Provoked  AUSTRALIA
# 14      2018.05.00     May 2018  2018.0      Provoked  AUSTRALIA
# 16      2018.05.09  09-May-2018  2018.0  Questionable  AUSTRALIA
# ...            ...          ...     ...           ...        ...
# 6294       ND.0008  Before 1906     0.0    Unprovoked  AUSTRALIA
# 6295       ND.0007  Before 1906     0.0    Unprovoked  AUSTRALIA
# 6296       ND.0006  Before 1906     0.0    Unprovoked  AUSTRALIA
# 6297       ND.0005  Before 1903     0.0    Unprovoked  AUSTRALIA
# 6298       ND.0004  Before 1903     0.0    Unprovoked  AUSTRALIA
#
#                    Area                Location        Activity  \
# 3       New South Wales      Arrawarra Headland         Surfing
# ...

# %%
# printing areas in south africa 
sharkAttacks_cleaned.loc[sharkAttacks['Country'] == 'AUSTRALIA'].Area.unique()
# Out:
# array(['Queensland', 'Western Australia', 'Victoria', 'New South Wales',
#        'South Australia', 'Tasmania', 'Northern Territory',
#        'Territory of Cocos (Keeling) Islands', 'Victoria ',
#        'Torres Strait', 'Queensland '], dtype=object)

# %%
# replacing area names for continuity 
sharkAttacks_replace =sharkAttacks.replace(['Victoria '], 'Victoria')

# %%
# Creating dataframe with Australian areas and long lat 
Aus_shark = {'Area': ['Victoria', 
          'Northern Territory',
          'South Australia',
          'Western Australia',
          'Queensland', 
          'New South Wales',
        'Tasmania',
        'Territory of Cocos (Keeling) Islands',
        'Torres Strait',
        'Queensland'], 
 'Lat': [-37.020100, 
         -19.491411, 
         -30.000233, 
         -25.042261, 
         -20.917574, 
         -31.840233,
        -41.640079,
        -12.164165,
        -10.181578,
        -20.917574], 
    'Long': [144.964600, 
             132.550964, 
             136.209152, 
             117.793221, 
             142.702789, 
             145.612793,
            146.315918,
            96.870956,
            142.26641,
            142.702789]}

# %%
Aus_shark_df = pd.DataFrame(data=Aus_shark)
Aus_shark_df
# Out:
#                                    Area        Lat        Long
# 0                              Victoria -37.020100  144.964600
# 1                    Northern Territory -19.491411  132.550964
# 2                       South Australia -30.000233  136.209152
# 3                     Western Australia -25.042261  117.793221
# 4                            Queensland -20.917574  142.702789
# 5                       New South Wales -31.840233  145.612793
# 6                              Tasmania -41.640079  146.315918
# 7  Territory of Cocos (Keeling) Islands -12.164165   96.870956
# 8                         Torres Strait -10.181578  142.266410
# 9                            Queensland -20.917574  142.702789

# %%
# printing areas in south africa 
sharkAttacks_cleaned.loc[sharkAttacks['Country'] == 'SOUTH AFRICA'].Area.unique()
# Out:
# array(['Western Cape Province', 'Eastern Cape Province', 'KwaZulu-Natal',
#        'Western Province',
#        'KwaZulu-Natal between Port Edward and Port St Johns'],
#       dtype=object)

# %%
# South africa shark data 
SA_sharkAttacks =sharkAttacks_cleaned.loc[sharkAttacks['Country'] == 'SOUTH AFRICA']

# %%
# replacing area names for continuity 
Cleaned_SA_sharkAttacks=SA_sharkAttacks.replace(['KwaZulu-Natal between Port Edward and Port St Johns'], 'KwaZulu-Natal')

# %%
# Replacing area names for continuity
Cleaned_SA_sharkAttacks.replace(['Western Province'], 'Western Cape Province').Area.unique()
# Out:
# array(['Western Cape Province', 'Eastern Cape Province', 'KwaZulu-Natal'],
#       dtype=object)

# %%
# Creating dict with south africa areas 
SA_shark = {'Area': 
            ['KwaZulu-Natal', 
             'Western Cape Province', 
             'Eastern Cape Province'], 
            'Lat': [-29.883333,
                    -33.918861, 
                    -30.362110], 
            'Long': [31.049999, 
                     18.423300, 
                     28.801413]}

# %%
# Creating dataframe with lat and long for south africa data 
SA_shark_df = pd.DataFrame(data=SA_shark)
SA_shark_df
# Out:
#                     Area        Lat       Long
# 0          KwaZulu-Natal -29.883333  31.049999
# 1  Western Cape Province -33.918861  18.423300
# 2  Eastern Cape Province -30.362110  28.801413

# %%
# Filtering based on country and checking for unique values in the area column
MEX_data = sharkAttacks_cleaned.loc[sharkAttacks['Country'] == 'MEXICO']
MEX_data.Area.unique()
# Out:
# array(['Quintana Roo', 'Sinaloa', 'Guerrero', 'Guerro', 'Baja California',
#        'Veracruz'], dtype=object)

# %%
# Replacing area names for continuity
MEX_data.replace(['Guerro'], 'Guerrero').Area.unique()
# Out:
# array(['Quintana Roo', 'Sinaloa', 'Guerrero', 'Baja California',
#        'Veracruz'], dtype=object)

# %%
# Creating dict with south africa areas 
MEX_shark = {'Area': 
            ['Quintana Roo', 
             'Sinaloa', 
             'Guerrero',
            'Baja California',
            'Veracruz'], 
            'Lat': [19.263021,
                    25.790466, 
                    18.020529,
                    32.522499,
                    19.173773], 
            'Long': [-87.450912, 
                    -108.985886, 
                     -99.662476,
                     -117.046623,
                     -96.134224]}

# %%
# Creating dataframe with lat and long for south africa data 
MEX_shark_df = pd.DataFrame(data=MEX_shark)
MEX_shark_df
# Out:
#               Area        Lat        Long
# 0     Quintana Roo  19.263021  -87.450912
# 1          Sinaloa  25.790466 -108.985886
# 2         Guerrero  18.020529  -99.662476
# 3  Baja California  32.522499 -117.046623
# 4         Veracruz  19.173773  -96.134224

# %%
# printing areas in BRAZIL
sharkAttacks_cleaned.loc[sharkAttacks['Country'] == 'BRAZIL'].Area.unique()
# Out:
# array(['Pernambuco', 'Fernando de Noronha', 'Rio de Janeiro'],
#       dtype=object)

# %%
# Creating dict with south africa areas 
BZ_shark = {'Area': 
            ['Pernambuco', 
             'Fernando de Noronha', 
             'Rio de Janeiro'], 
            'Lat': [-8.472372,
                    -3.853808,
                     -22.908333], 
            'Long': [-37.946777, 
                    -32.423786, 
                     -43.196388]}

# %%
# Creating dataframe with lat and long for BRAZIL data 
BZ_shark_df = pd.DataFrame(data=BZ_shark)
BZ_shark_df
# Out:
#                   Area        Lat       Long
# 0           Pernambuco  -8.472372 -37.946777
# 1  Fernando de Noronha  -3.853808 -32.423786
# 2       Rio de Janeiro -22.908333 -43.196388

# %%
ENG_data = sharkAttacks.loc[sharkAttacks['Country'] == 'ENGLAND']
ENG_data
# Out:
#        Case Number                  Date    Year        Type  Country  \
# 13    2018.05.13.a           13-May-2018  2018.0     Invalid  ENGLAND
# 1213  2008.08.30.a           30-Aug-2008  2008.0    Provoked  ENGLAND
# 1376  2007.05.17.R  Reported 17-May-2007  2007.0    Provoked  ENGLAND
# 2073    2000.02.14           14-Feb-2000  2000.0    Provoked  ENGLAND
# 3024  1981.06.15.R  Reported 15-Jun-1981  1981.0        Boat  ENGLAND
# 3406  1970.01.09.R  Reported 09-Jan-1970  1970.0  Unprovoked  ENGLAND
# 3426    1969.07.27           27-Jul-1969  1969.0    Provoked  ENGLAND
# 3471    1968.06.00              Jun-1968  1968.0  Unprovoked  ENGLAND
# 3975  1960.08.04.b           04-Aug-1960  1960.0    Provoked  ENGLAND
# 5164    1925.09.03           03-Sep-1925  1925.0  Unprovoked  ENGLAND
# 5180    1924.07.14           14-Jul-1924  1924.0    Provoked  ENGLAND
# 5220  1922.09.26.R  Reported 26-Sep-1922  1922.0  Unprovoked  ENGLAND
# ...

# %%
# Creating dict with ENGLAND areas 
ENG_shark = {'Area': 
            ['Cornwall', 
             'Kent'], 
            'Lat': [50.503632,
                    47.378010], 
            'Long': [-4.652498, 
                    -122.237381]}

# %%
# Creating dataframe with lat and long for BRAZIL data 
ENG_shark_df = pd.DataFrame(data=ENG_shark)
ENG_shark_df
# Out:
#        Area        Lat        Long
# 0  Cornwall  50.503632   -4.652498
# 1      Kent  47.378010 -122.237381

# %%
# printing areas in THAILAND
sharkAttacks_cleaned.loc[sharkAttacks['Country'] == 'THAILAND'].Area.unique()
# Out:
# array(['Phuket'], dtype=object)

# %%
sharks = {
    'Area':
    ['Phuket',
    'Cocos Island',
    'Alifu Alifu Atoll'],
    'Lat': [7.878978,
           5.528228,
           4.215128],
    'Long': [98.398392,
            -87.05743,
            72.864471]
}

# %%
# Creating dataframe with lat and long for THAILAND data 
shark_df = pd.DataFrame(data=sharks)
shark_df
# Out:
#                 Area       Lat       Long
# 0             Phuket  7.878978  98.398392
# 1       Cocos Island  5.528228 -87.057430
# 2  Alifu Alifu Atoll  4.215128  72.864471

# %%
# printing areas in BAHAMAS
BAH_sharks = sharkAttacks.loc[sharkAttacks['Country'] == 'BAHAMAS']

# %%
# printing areas in THAILAND
BAH_sharks.loc[BAH_sharks['Country'] == 'BAHAMAS'].Area.unique()
# Out:
# array(['New Providence ', 'Abaco Islands', 'Exuma Islands', 'West End',
#        'Northern Bahamas', 'Grand Bahama Island', 'Berry Islands',
#        'Walkers Cay', 'Out Islands', 'Cat Cay', 'Cay Sal Bank',
#        'Andros Islands'], dtype=object)

# %%
BAH_sharks.replace(['New Providence '], 'New Providence')
# Out:
#        Case Number         Date    Year        Type  Country  \
# 138     2017.06.02  02-Jun-2017  2017.0  Unprovoked  BAHAMAS
# 460     2015.01.06  06-Jan-2015  2015.0  Unprovoked  BAHAMAS
# 646   2013.07.29.c  28-Jul-2013  2013.0  Unprovoked  BAHAMAS
# 649   2013.07.28.b  28-Jul-2013  2013.0  Unprovoked  BAHAMAS
# 952     2011.01.26  26-Jan-2011  2011.0  Unprovoked  BAHAMAS
# 1287    2008.02.24  24-Feb-2008  2008.0  Unprovoked  BAHAMAS
# 1323    2007.09.28  28-Sep-2007  2007.0  Unprovoked  BAHAMAS
# 1363    2007.07.10  10-Jul-2007  2007.0  Unprovoked  BAHAMAS
# 1673    2004.05.18  18-May-2004  2004.0    Provoked  BAHAMAS
# 1756    2003.07.09  10-Jul-2003  2003.0  Unprovoked  BAHAMAS
# 1759    2003.07.04  04-Jul-2003  2003.0  Unprovoked  BAHAMAS
# 1870    2002.04.09  09-Apr-2002  2002.0  Unprovoked  BAHAMAS
# 1911    2001.08.31  31-Aug-2001  2001.0  Unprovoked  BAHAMAS
# 1924    2001.08.16  16-Aug-2001  2001.0  Unprovoked  BAHAMAS
# ...

# %%
BAHAMAS_sharks = {
    'Area':
    ['New Providence',
    'Abaco Islands',
    'Exuma Islands',
    'West End',
    'Northern Bahamas',
    'Grand Bahama Island',
    'Berry Islands',
    'Walkers Cay',
    'Out Islands',
    'Cat Cay',
    'Cay Sal Bank',
    'Andros Islands'],
    'Lat': [25.051928,
           26.467,
           23.533,
           26.68711,
           25.025885,
           26.659447,
           25.5667,
           25.083333,
           25.025885,
           25.55625,
           23.688889,
           24.433333],
    'Long': [-77.40134,
            -77.083,
            -75.833,
            -78.97702,
            -78.035889,
            -78.52065,
            -77.7500,
            -78.016667,
            -78.035889,
            -79.277139,
            -80.390556,
            -77.95]
}

# %%
# Creating dataframe with lat and long for BAHAMAS data 
BAHAMAS_sharks_df = pd.DataFrame(data= BAHAMAS_sharks)
BAHAMAS_sharks_df
# Out:
#                    Area        Lat       Long
# 0        New Providence  25.051928 -77.401340
# 1         Abaco Islands  26.467000 -77.083000
# 2         Exuma Islands  23.533000 -75.833000
# 3              West End  26.687110 -78.977020
# 4      Northern Bahamas  25.025885 -78.035889
# 5   Grand Bahama Island  26.659447 -78.520650
# 6         Berry Islands  25.566700 -77.750000
# 7           Walkers Cay  25.083333 -78.016667
# 8           Out Islands  25.025885 -78.035889
# 9               Cat Cay  25.556250 -79.277139
# 10         Cay Sal Bank  23.688889 -80.390556
# 11       Andros Islands  24.433333 -77.950000

# %%
# printing areas in BAHAMAS
NEWCAL_sharks = sharkAttacks_cleaned.loc[sharkAttacks['Country'] == 'NEW CALEDONIA']

# %%
NEW_CAL_sharks = sharkAttacks.loc[sharkAttacks['Country'] == 'NEW CALEDONIA'].Area.unique()
NEW_CAL_sharks
# Out:
# array([nan, 'North Province', 'Grand Terre', 'South Province',
#        'Baie de Sainte-Marie', ' Loyalty Islands', 'Loyalty Islands'],
#       dtype=object)

# %%
NEWCAL_sharks.replace([' Loyalty Islands'], 'Loyalty Islands')
# Out:
#        Case Number         Date    Year        Type        Country  \
# 288     2016.04.09  09-Apr-2016  2016.0  Unprovoked  NEW CALEDONIA
# 590     2013.12.25  25-Dec-2013  2013.0  Unprovoked  NEW CALEDONIA
# 923   2011.05.21.a  21-May-2011  2011.0  Unprovoked  NEW CALEDONIA
# 943     2011.02.23  23-Feb-2011  2011.0  Unprovoked  NEW CALEDONIA
# 1260  2008.05.07.b  07-May-2008  2008.0  Unprovoked  NEW CALEDONIA
# 1266  2008.04.26.b  26-Apr-2008  2008.0  Unprovoked  NEW CALEDONIA
# 1322  2007.09.30.a  30-Sep-2007  2007.0  Unprovoked  NEW CALEDONIA
# 1390    2007.04.09  09-Apr-2007  2007.0  Unprovoked  NEW CALEDONIA
# 1404  2007.01.25.b  25-Jan-2007  2007.0  Unprovoked  NEW CALEDONIA
# 2064    2000.03.15  15-Mar-2000  2000.0  Unprovoked  NEW CALEDONIA
#
#                  Area                       Location  \
# 288       Grand Terre                      Poe Beach
# 590    North Province        Lindéralique, Hienghène
# 923    North Province                         Kendec
# ...

# %%
N_CALEDONIA_sharks = {
    'Area':
    ['Grand Terre',
    'North Province',
    'Loyalty Islands',
    'South Province'],
    'Lat': [-21.283333,
            -21,
            -21.066667,
            -21.916667],
    'Long': [165.35,
             165,
             167.35,
             166.333333]
}

# %%
# Creating dataframe with lat and long for NEW CALEDONIA data 
N_CALEDONIA_df = pd.DataFrame(data= N_CALEDONIA_sharks)
N_CALEDONIA_df
# Out:
#               Area        Lat        Long
# 0      Grand Terre -21.283333  165.350000
# 1   North Province -21.000000  165.000000
# 2  Loyalty Islands -21.066667  167.350000
# 3   South Province -21.916667  166.333333

# %%
, 'NEW CALEDONIA',
       'ECUADOR', 'MALAYSIA', 'LIBYA', nan, 'CUBA', 'MAURITIUS',
       'NEW ZEALAND', 'SPAIN', 'SAMOA', 'SOLOMON ISLANDS', 'JAPAN',
       'EGYPT', 'ST HELENA, British overseas territory', 'COMOROS',
       'REUNION', 'FRENCH POLYNESIA', 'UNITED KINGDOM',
       'UNITED ARAB EMIRATES', 'PHILIPPINES', 'INDONESIA', 'CHINA',
       'COLUMBIA', 'CAPE VERDE', 'Fiji', 'DOMINICAN REPUBLIC'
