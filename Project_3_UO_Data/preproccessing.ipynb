# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
shark_attack = pd.read_csv('sharkattack.csv')
shark_attack = shark_attack.drop(columns=['Unnamed: 8', 'Unnamed: 9'])
shark_attack = shark_attack.dropna()
shark_attack.to_csv('firstclean.csv')
shark_attack.head()
# Out:
#           Area        Activity Sex  Age  \
# 0   California        Paddling    F  57
# 6   Pernambuco        Swimming    M  18
# 8      Florida         Walking    M  15
# 10  Queensland  Feeding sharks    M  32
# 13    Cornwall         Fishing    M  21
#
#                                                Injury Fatal (Y/N)  \
# 0   No injury to occupant, outrigger canoe and pad...           N
# 6                                               FATAL           Y
# 8                               Lower left leg bitten           N
# 10  Minor bite to hand by captive shark. PROVOKED ...           N
# 13  Injured by teeth of a dead porbeagle shark he ...           N
#
#               Time          Species
# 0            18h00       White shark
# 6   Late afternoon       Tiger shark
# 8            17h00    Bull shark, 6'
# 10         Morning   Grey reef shark
# 13           08h15  Invalid incident

# %%
#unique_area = shark_attack['Area'].unique()
#unique_country = shark_attack['Country'].unique()
#unique_area_df = pd.DataFrame(unique_area)
#unique_country_df = pd.DataFrame(unique_country)
#unique_area_df.to_csv('Unique_Area.csv')
#unique_country_df.to_csv('Unique_Country.csv')

# %%
test1 = pd.read_csv('second_clean.csv')
test1.info()
test1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1435 entries, 0 to 1434
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Area        1435 non-null   object
#  1   Activity    1435 non-null   object
#  2   Sex         1435 non-null   object
#  3   Age         1435 non-null   int64
#  4   Injury      1435 non-null   object
#  5   Fatal(Y/N)  1435 non-null   object
#  6   Time        1435 non-null   object
#  7   Species     1435 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 89.8+ KB
#               Area                                           Activity Sex   \
# 0       California                                           Paddling    F
# 1       Pernambuco                                           Swimming    M
# 2          Florida                                            Walking    M
# 3       Queensland                                     Feeding sharks    M
# ...

# %%
X = test1.drop(labels='Fatal(Y/N)', axis=1)
#X = np.array(X)
#print(X)
    
#     define label
y = test1['Fatal(Y/N)']

# %%
from sklearn.model_selection import train_test_split
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=1)

#from sklearn.linear_model import LogisticRegression
#classifier = LogisticRegression()

from sklearn.ensemble import RandomForestClassifier
classifier = LogisticRegression()

classifier.fit(X_train, y_train)

print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")

predictions = classifier.predict(X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].tolist()}")

pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-67292801135e> in <module>
#       6 classifier = LogisticRegression()
#       7
# ----> 8 classifier.fit(X_train, y_train)
#       9
#      10 print(f"Training Data Score: {classifier.score(X_train, y_train)}")
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1342         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1343                                    order="C",
# -> 1344                                    accept_large_sparse=solver != 'liblinear')
#    1345         check_classification_targets(y)
#    1346         self.classes_ = np.unique(y)
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
# ...
